# %%
import json
from pprint import pprint
import pandas as pd
import os
# %matplotlib inline
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer
pd.options.display.mpl_style = 'default'
# Out:
# /Users/heathercohen/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150301.json')
df2=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150302.json')
df3=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150303.json')
df4=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150304.json')
df5=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150305.json')
df6=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150306.json')
df7=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150307.json')
df8=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150308.json')
df9=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150309.json')
df10=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150310.json')
df11=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150311.json')
df12=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150312.json')
df13=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150313.json')
df14=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150314.json')
df15=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150315.json')
df16=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150316.json')
df17=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150317.json')
df18=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150318.json')
df19=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150319.json')
df20=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150320.json')
df21=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150321.json')
df22=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150322.json')
df23=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150323.json')
df24=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150324.json')
df25=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150325.json')
df26=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150326.json')
df27=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150327.json')
df28=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150328.json')
df29=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150329.json')
df30=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150330.json')
df31=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150331.json')
df32=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150401.json')
df33=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150402.json')
df34=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150403.json')
df35=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150404.json')
df36=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150405.json')
df37=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150406.json')
df38=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150407.json')
df39=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150408.json')
df40=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150409.json')
df41=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150410.json')
df42=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150411.json')
df43=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150412.json')
df44=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150413.json')
df45=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150414.json')
df46=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150415.json')
df47=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150416.json')
df48=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150417.json')
df49=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150418.json')
df50=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150419.json')
df51=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150420.json')
df52=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150421.json')
df53=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150422.json')
df54=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150423.json')
df55=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150424.json')
df56=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150425.json')
df57=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150426.json')
df58=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150427.json')
df59=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150428.json')
df60=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150429.json')
df61=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150430.json')
df62=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150501.json')
df63=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150502.json')
df64=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150503.json')
df65=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150504.json')
df66=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150505.json')
df67=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150506.json')
df68=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150507.json')
df69=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150508.json')
df70=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150509.json')
df71=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150510.json')
df72=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150511.json')
df73=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150512.json')
df74=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150513.json')
df75=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150514.json')
df76=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150515.json')
df77=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150516.json')
df78=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150517.json')
df79=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150518.json')
df80=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150519.json')
df81=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150520.json')
df82=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150521.json')
df83=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150522.json')
df84=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150523.json')
df85=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150524.json')
df86=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150525.json')
df87=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150526.json')
df88=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150527.json')
df89=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150528.json')
df90=pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/usage_20150529.json')

df1['date'] = pd.Series('20150301' , index = df1.index)
df2['date'] = pd.Series('20150302' , index = df2.index)
df3['date'] = pd.Series('20150303' , index = df3.index)
df4['date'] = pd.Series('20150304' , index = df4.index)
df5['date'] = pd.Series('20150305' , index = df5.index)
df6['date'] = pd.Series('20150306' , index = df6.index)
df7['date'] = pd.Series('20150307' , index = df7.index)
df8['date'] = pd.Series('20150308' , index = df8.index)
df9['date'] = pd.Series('20150309' , index = df9.index)
df10['date'] = pd.Series('20150310' , index = df10.index)
df11['date'] = pd.Series('20150311' , index = df11.index)
df12['date'] = pd.Series('20150312' , index = df12.index)
df13['date'] = pd.Series('20150313' , index = df13.index)
df14['date'] = pd.Series('20150314' , index = df14.index)
df15['date'] = pd.Series('20150315' , index = df15.index)
df16['date'] = pd.Series('20150316' , index = df16.index)
df17['date'] = pd.Series('20150317' , index = df17.index)
df18['date'] = pd.Series('20150318' , index = df18.index)
df19['date'] = pd.Series('20150319' , index = df19.index)
df20['date'] = pd.Series('20150320' , index = df20.index)
df21['date'] = pd.Series('20150321' , index = df21.index)
df22['date'] = pd.Series('20150322' , index = df22.index)
df23['date'] = pd.Series('20150323' , index = df23.index)
df24['date'] = pd.Series('20150324' , index = df24.index)
df25['date'] = pd.Series('20150325' , index = df25.index)
df26['date'] = pd.Series('20150326' , index = df26.index)
df27['date'] = pd.Series('20150327' , index = df27.index)
df28['date'] = pd.Series('20150328' , index = df28.index)
df29['date'] = pd.Series('20150329' , index = df29.index)
df30['date'] = pd.Series('20150330' , index = df30.index)
df31['date'] = pd.Series('20150331' , index = df31.index)
df32['date'] = pd.Series('20150401' , index = df32.index)
df33['date'] = pd.Series('20150402' , index = df33.index)
df34['date'] = pd.Series('20150403' , index = df34.index)
df35['date'] = pd.Series('20150404' , index = df35.index)
df36['date'] = pd.Series('20150405' , index = df36.index)
df37['date'] = pd.Series('20150406' , index = df37.index)
df38['date'] = pd.Series('20150407' , index = df38.index)
df39['date'] = pd.Series('20150408' , index = df39.index)
df40['date'] = pd.Series('20150409' , index = df40.index)
df41['date'] = pd.Series('20150410' , index = df41.index)
df42['date'] = pd.Series('20150411' , index = df42.index)
df43['date'] = pd.Series('20150412' , index = df43.index)
df44['date'] = pd.Series('20150413' , index = df44.index)
df45['date'] = pd.Series('20150414' , index = df45.index)
df46['date'] = pd.Series('20150415' , index = df46.index)
df47['date'] = pd.Series('20150416' , index = df47.index)
df48['date'] = pd.Series('20150417' , index = df48.index)
df49['date'] = pd.Series('20150418' , index = df49.index)
df50['date'] = pd.Series('20150419' , index = df50.index)
df51['date'] = pd.Series('20150420' , index = df51.index)
df52['date'] = pd.Series('20150421' , index = df52.index)
df53['date'] = pd.Series('20150422' , index = df53.index)
df54['date'] = pd.Series('20150423' , index = df54.index)
df55['date'] = pd.Series('20150424' , index = df55.index)
df56['date'] = pd.Series('20150425' , index = df56.index)
df57['date'] = pd.Series('20150426' , index = df57.index)
df58['date'] = pd.Series('20150427' , index = df58.index)
df59['date'] = pd.Series('20150428' , index = df59.index)
df60['date'] = pd.Series('20150429' , index = df60.index)
df61['date'] = pd.Series('20150430' , index = df61.index)
df62['date'] = pd.Series('20150501' , index = df62.index)
df63['date'] = pd.Series('20150502' , index = df63.index)
df64['date'] = pd.Series('20150503' , index = df64.index)
df65['date'] = pd.Series('20150504' , index = df65.index)
df66['date'] = pd.Series('20150505' , index = df66.index)
df67['date'] = pd.Series('20150506' , index = df67.index)
df68['date'] = pd.Series('20150507' , index = df68.index)
df69['date'] = pd.Series('20150508' , index = df69.index)
df70['date'] = pd.Series('20150509' , index = df70.index)
df71['date'] = pd.Series('20150510' , index = df71.index)
df72['date'] = pd.Series('20150511' , index = df72.index)
df73['date'] = pd.Series('20150512' , index = df73.index)
df74['date'] = pd.Series('20150513' , index = df74.index)
df75['date'] = pd.Series('20150514' , index = df75.index)
df76['date'] = pd.Series('20150515' , index = df76.index)
df77['date'] = pd.Series('20150516' , index = df77.index)
df78['date'] = pd.Series('20150517' , index = df78.index)
df79['date'] = pd.Series('20150518' , index = df79.index)
df80['date'] = pd.Series('20150519' , index = df80.index)
df81['date'] = pd.Series('20150520' , index = df81.index)
df82['date'] = pd.Series('20150521' , index = df82.index)
df83['date'] = pd.Series('20150522' , index = df83.index)
df84['date'] = pd.Series('20150523' , index = df84.index)
df85['date'] = pd.Series('20150524' , index = df85.index)
df86['date'] = pd.Series('20150525' , index = df86.index)
df87['date'] = pd.Series('20150526' , index = df87.index)
df88['date'] = pd.Series('20150527' , index = df88.index)
df89['date'] = pd.Series('20150528' , index = df89.index)
df90['date'] = pd.Series('20150529' , index = df90.index)

# %%
March2015 = [df1,
df2,
df3,
df4,
df5,
df6,
df7,
df8,
df9,
df10,
df11,
df12,
df13,
df14,
df15,
df16,
df17,
df18,
df19,
df20,
df21,
df22,
df23,
df24,
df25,
df26,
df27,
df28,
df29,
df30,
df31]
 
April2015 = [df32,
df33,
df34,
df35,
df36,
df37,
df38,
df39,
df40,
df41,
df42,
df43,
df44,
df45,
df46,
df47,
df48,
df49,
df50,
df51,
df52,
df53,
df54,
df55,
df56,
df57,
df58,
df59,
df60,
df61]
 
May2015=[df62,
df63,
df64,
df65,
df66,
df67,
df68,
df69,
df70,
df71,
df72,
df73,
df74,
df75,
df76,
df77,
df78,
df79,
df80,
df81,
df82,
df83,
df84,
df85,
df86,
df87,
df88,
df89,
df90]

# %%
Marchresult = pd.concat(March2015)
Aprilresult =  pd.concat(April2015)
Mayresult =pd.concat(May2015)
 
frame =[Marchresult, Aprilresult, Mayresult]
results = pd.concat(frame)

# %%
Aprilresult
# Out:
#        buzzid deviceType  nCompletes  nShares  nViews  \
# 0     3738763     mobile      357876    18208  424572
# 1     3740434     mobile      161099     3464  199885
# 2     3738763    desktop      132018     5263  152246
# 3     3740434    desktop      104897      919  126598
# 4     3739285     mobile       79783      522   95978
# 5     3739260     mobile       54845      469   66751
# 6     3737576     mobile       52847     2755   63861
# 7     3739646    desktop       53152      147   58616
# 8     3741312    desktop       54900       75   57948
# 9     3740806    desktop       49199      134   57055
# 10    3740537    desktop       48068      205   53808
# 11    3741501    desktop       45574      188   51177
# 12    3740675    desktop       39236      159   46960
# 13    3737222    desktop       33210       11   43085
# 14    3738763     tablet       33611     2472   42559
# 15    3739552     mobile       17351       82   41623
# ...

# %%
Mayresult
# Out:
#        buzzid deviceType  nCompletes  nShares  nViews  \
# 0     3742323    desktop      151372       52  160884
# 1     3742323     mobile      108652      133  115140
# 2     3768598    desktop       72080       30   77875
# 3     3768598     mobile       60632       60   66373
# 4     3767617    desktop       62083       85   66247
# 5     3767552     mobile       55624     1885   64809
# 6     3767552    desktop       45350      523   50411
# 7     3767633    desktop       43691       86   47583
# 8     3766774    desktop       40362      154   45568
# 9     3766946    desktop       37086       80   43759
# 10    3767617     mobile       37453      132   41539
# 11    3766774     mobile       32210      483   39760
# 12    3761524     mobile       23729      972   38430
# 13    3766946     mobile       29670      189   37485
# 14    3765864    desktop       17739      104   33674
# 15    3768751    desktop       24802       72   33117
# ...

# %%
results.index = results['date']

# %%
results['deviceType'].value_counts().sort_values()
# Out:
# tablet     14452
# desktop    35321
# mobile     45792
# Name: deviceType, dtype: int64

# %%
results['deviceType'].value_counts().plot.bar()

# %%
metadf = pd.read_json('/Users/heathercohen/Documents/Personal/quiz_v20160529/metadata.json')

# %%
metadf['published'] = pd.to_datetime(metadf['published'],unit='s')
metadf['date'] = metadf['published']
metadf = metadf.drop('published', 1)

# %%
metadf.index = metadf['date']

# %%
words = ' '.join(metadf['title'])

# %%
from scipy.misc import imread
wordcloud = WordCloud(
                      font_path='/Users/heathercohen/Library/Fonts/roboto/Roboto-Bold.ttf',
                      stopwords=STOPWORDS,
                      background_color='white',
                      width=5000,
                      height=3000,
                     ).generate(words)

plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('./my_twitter_wordcloud_3.png', dpi=900)
plt.show()

# %%
blob = TextBlob(words)

# %%
from collections import Counter
Counter(blob.noun_phrases).most_common(50)
# Out:
# [('guess', 230),
#  ('well', 216),
#  ('know', 196),
#  ('character', 185),
#  ('remember', 92),
#  ('quiz', 83),
#  ('your', 77),
#  ('who', 75),
#  ('kind', 69),
#  ('have', 66),
#  ('lyrics', 54),
#  ('ever', 49),
#  ('hardest', 47),
#  ('seen', 46),
#  ('be', 45),
#  ('your soulmate', 44),
#  ('harry potter', 41),
#  ('name', 37),
#  ('identify', 36),
#  ('belong', 34),
#  ('type', 34),
#  ('celebrity', 31),
#  ('live', 30),
#  ('game', 27),
#  ('guess your age based', 25),
#  ('match', 24),
#  ('date', 24),
#  ('thrones', 23),
#  ('taylor swift', 22),
#  ('member', 21),
#  ('disney', 21),
#  ('your taste', 20),
#  ('movie', 20),
#  ('based', 19),
#  ('sex', 19),
#  ('read', 19),
#  ('will', 18),
#  ('emojis', 18),
#  ('real', 18),
#  ('survive', 17),
#  ('right', 17),
#  ('marry', 16),
#  ('weekend', 16),
#  ('pass', 16),
#  ('guy', 15),
#  ('repeat', 15),
#  ('theme', 15),
#  ('hook up', 14),
#  ('men', 13),
#  ('really', 13)]

# %%
metadf['quizType'].value_counts().plot.bar()

# %%
Counter(blob.words).most_common(20)
# Out:
# [('You', 2473),
#  ('Are', 1032),
#  ('Which', 938),
#  ('The', 730),
#  ('Your', 710),
#  ('How', 644),
#  ('Can', 537),
#  ('Of', 444),
#  ('What', 441),
#  ('Do', 401),
#  ('Guess', 343),
#  ('Should', 323),
#  ('Or', 289),
#  ('A', 271),
#  ('Is', 262),
#  ('Character', 254),
#  ('These', 249),
#  ('Know', 246),
#  ('We', 230),
#  ('In', 222)]

# %%
Counter(blob.words).most_common()[:-10-1:-1]
# Out:
# [('Thousand', 1),
#  ('¿Estás', 1),
#  ('Albertan', 1),
#  ('Fancy', 1),
#  ('votar', 1),
#  ('Unfffff', 1),
#  ('Solid', 1),
#  ('Quels', 1),
#  ('Hidden', 1),
#  ('matarte', 1)]

# %%
results['buzzid'].plot.hist()

# %%
byid= results, metadf
buzzfeediddf= pd.concat(byid, keys='buzzid')
buzzfeediddf.index = buzzfeediddf['date']
buzzfeediddf= buzzfeediddf.drop('published', 1)

# %%
buzzfeediddf.index = buzzfeediddf['date']

# %%
byid =pd.DataFrame()
byid['date']=buzzfeediddf['date']
byid['buzzid']=buzzfeediddf['buzzid']
byid['counts']=byid['buzzid'].value_counts()
byid.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
buzzfeediddf['nViews'].plot()

# %%
buzzfeediddf.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
newdf = pd.DataFrame()

newdf['nQuestions']= buzzfeediddf['nQuestions']
newdf['nCompletes']=buzzfeediddf['nCompletes']
newdf['buzzid']=buzzfeediddf['buzzid']
newdf['date']=buzzfeediddf['date']
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 258

# %%
newdf.index = newdf['date']

# %%
newdf.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
metadf['nQuestions'].plot.bar()

# %%
metadf['nQuestions'].value_counts().plot.bar()

# %%
metadf['nQuestions'].plot.hist()

# %%
buzzfeediddf.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
sums= buzzfeediddf.reset_index().groupby("buzzid").sum()

# %%
sumstype= buzzfeediddf.reset_index().groupby("quizType")

# %%
sums.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
sumstype

# %%
sums['nQuestions'].corr(sums['nCompletes'])
# Out:
# -0.066865241421112789

# %%
sums['nQuestions'].corr(sums['nShares'])
# Out:
# 0.012007769737477039

# %%
sumsdate.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')
